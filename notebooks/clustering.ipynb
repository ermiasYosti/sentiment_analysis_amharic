# %%
import pandas as pd
import numpy as np
import pickle
import os
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
DATA_FILE_PATH = 'C:\\Users\\Yostina\\SentimentNLP\\'
DATA_FILE_NAME = 'sentiment_mapped_datas4.csv'
SAVE_FILE = True

# %%
df = pd.read_csv(DATA_FILE_PATH+DATA_FILE_NAME,encoding="utf-8" )

# %%
del df['Region']
del df['Sex']
del df['Edu_Level']
del df['Feedback']
del df['tokens']
del df['category']

# %%
da=df.to_csv("C://Users//Yostina//SentimentNLP//sentiment_cluster.csv",index = False)

# %%
plt.scatter(df['Age'],df['sentiment'])
plt.ylabel('Polarity')
plt.xlabel('year')
plt.show()

# %%
df1 = pd.read_csv("C://Users//Yostina//SentimentNLP//sentiment_cluster2.csv",encoding="utf-8" )
x=df1.copy()

# %%
kmeans=KMeans(2)

# %%
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
clusters=x.copy()

# %%
clusters['cluster_pred']=kmeans.fit(x)

# %%
plt.scatter(clusters['Fb_Month'],clusters['sentiment'],c=clusters['cluster_pred'],cmap='rainbow')
plt.title('Which Gender give more feedback?', fontsize=20)
plt.ylabel('Polarity')
plt.xlabel('year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-2dd4b490f326> in <module>
# ----> 1 plt.scatter(clusters['Fb_Month'],clusters['sentiment'],c=clusters['cluster_pred'],cmap='rainbow')
#       2 plt.title('Which Gender give more feedback?', fontsize=20)
#       3 plt.ylabel('Polarity')
#       4 plt.xlabel('year')
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
predicted_class = kmeans.predict([[1, 10, 15]])
print(predicted_class)
